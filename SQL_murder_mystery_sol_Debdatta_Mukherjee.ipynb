# %% [markdown]
# <a href="https://colab.research.google.com/github/Debdatta7/PrepInsta-Internship/blob/main/SQL_murder_mystery_sol_Debdatta_Mukherjee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SQL Murder Mystery

# %%
import pandas as pd
import sqlite3 as sql

# %%
con = sql.connect("/content/drive/MyDrive/Data analytics project/Week5/sql-murder-mystery.db")

# %% [markdown]
# #### Retrieve Crime Scene Report:

# %%
query = """
SELECT *
FROM crime_scene_report
WHERE City = "SQL City"
ORDER BY date;
"""
pd.set_option('display.max_colwidth',None)
pd.read_sql_query(query,con)
# Out:
#        date     type  \
# 0  20170712    theft
# 1  20170820    arson
# 2  20171110  robbery
# 3  20180103  bribery
# 4  20180115  assault
# 5  20180115  assault
# 6  20180115   murder
# 7  20180215   murder
# 8  20180215   murder
#
#                                                                                                                                                                                                                                                               description  \
# 0              A lone hunter stalks the night, firing arrows into the Darkness.\n            There is no hiding, no escape. In the distance, the beast\n            falters, tethered to the void. The killing blow comes without\n            hesitation, without mercy.
# ...

# %% [markdown]
# #### Witness Personal Details:

# %%
# Witness 1

query = """
SELECT *
FROM person
WHERE address_street_name = 'Northwestern Dr'
ORDER BY address_number;
"""
pd.read_sql_query(query,con)
# Out:
#        id                  name  license_id  address_number  \
# 0   89906       Kinsey Erickson      510019             309
# 1   15171          Weldon Penso      336999             311
# 2   40336       Fredia Billeter      251082             404
# 3   85280             Donn Duin      569122             540
# 4   12711        Norman Apolito      667757             599
# 5   75484          Del Tacderen      447887             607
# 6   26758      Angelena Billman      942074             629
# 7   39688            Abe Roeker      537445             689
# 8   10010             Muoi Cary      385336             741
# 9   40760          Renata Faver      976650             745
# 10  25615         Olevia Morena      388477             812
# 11  99826          Ivy Kazarian      994470             892
# 12  44542        Ivory Mcgrevey      873842             897
# 13  55130        Shiloh Huntoon      472118             951
# 14  33415         Homer Simpson      108392             981
# ...

# %%
# Witness 2

query = """
SELECT *
FROM person
WHERE address_street_name = 'Franklin Ave'
AND name LIKE '%Annabel%';
"""
pd.read_sql_query(query,con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# #### View Witness Interviews:

# %%
# Witness 1

query = """
SELECT *
FROM interview
WHERE person_id = '16371';
"""
pd.read_sql_query(query,con)
# Out:
#    person_id  \
# 0      16371
#
#                                                                                                               transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
# Witness 2

query = """
SELECT *
FROM interview
WHERE person_id = '14887';
"""
pd.read_sql_query(query,con)
# Out:
#    person_id  \
# 0      14887
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# #### Check Gym Database:

# %%
query = """
SELECT *
FROM get_fit_now_check_in
WHERE check_in_date = '20180109'
AND membership_id LIKE '48Z%';
"""
pd.read_sql_query(query,con)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %% [markdown]
# #### Check Car Details:

# %%
query = """
SELECT *
FROM drivers_license
WHERE plate_number LIKE '%H42W%';
"""
pd.read_sql_query(query,con)
# Out:
#        id  age  height eye_color hair_color  gender plate_number   car_make  \
# 0  183779   21      65      blue     blonde  female       H42W0X     Toyota
# 1  423327   30      70     brown      brown    male       0H42W2  Chevrolet
# 2  664760   21      71     black      black    male       4H42WR     Nissan
#
#   car_model
# 0     Prius
# 1  Spark LS
# 2    Altima

# %% [markdown]
# #### Personal Details:

# %%
# Witness 1

query = """
SELECT *
FROM person
WHERE license_id = '423327';
"""
pd.read_sql_query(query,con)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %%
# Witness 2

query = """
SELECT *
FROM person
WHERE license_id = '664760';
"""
pd.read_sql_query(query,con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  51739  Tushar Chandra      664760             312              Phi St
#
#          ssn
# 0  137882671

# %% [markdown]
# #### Membership Status at the Gym:

# %%
query = """
SELECT *
FROM get_fit_now_member
WHERE membership_status = 'gold'
AND id LIKE '48Z%';
"""
pd.read_sql_query(query,con)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# ####  I N V E S T I G A T I O N    R E P O R T
#
# Jeremy Bowers is the murderer!!!
#
#  Because of the following reasons:
#  1. From the crime scene report we can find that we have two witnesses,
#   1. One who lives at the last house on "Northwestern Dr"
# 	2. And the other whose name is "Annabel" and lives somewhere on "Franklin Ave"
#
# 2. (a) Our first witness 'Annabel' said that she saw the murderer last week on her gym on 09.01.2018,
#   (b) Our second witness 'Morty Schapiro' said that:
#    1.	He saw a man running out, after hearing a gunshot.
#    2.	He had a "Get Fit Now Gym" bag
#    3. The membership number started with "48Z" - Only "Gold Members" have that kind of bag.
#    4.	The man got into a car whose number plate included the following initials - "H42W"
#
# 3. After getting the car details, I found out that there were total 3 persons (1 Female and 2 Males) with the number plate including "H42W" in it.
#   1. Suspect 1 : Jeremy Bowers/ ID: 67318 <--<
#   2. Suspect 2 : Tushar Chandra/ ID: 51739
#
# 4. After reviewing the membership status of the gym, I found out that there were 2 persons with the "Gold Membership" and "48Z" initials on their gym bag.
#   1. Suspect 1 : Joe Germuska
#   2. Suspect 2 : Jeremy Bowers <--<
#
# 5. After analysing,
# 	 I found out that the murderer was 'Jeremy Bowers' who was a gold member at the gym, with bag no: "48Z55" who murdered on 15.01.2018, and
# 	 then fled with his car having number plate "0H42W2".
